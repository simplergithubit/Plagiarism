# %%
# !git clone https://github.com/me-badsha/Plagiarism-checker.git
# Out:
# Cloning into 'Plagiarism-checker'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 29 (delta 12), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (29/29), 6.77 KiB | 1.69 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
cd Plagiarism-checker
# Out:
# /content/Plagiarism-checker

# %%
# !pip3 install -r requirements.txt
# Out:
# Collecting scikit_learn==0.24.2 (from -r requirements.txt (line 1))
#   Downloading scikit-learn-0.24.2.tar.gz (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 39.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (pyproject.toml) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !python3 acode.py
# Out:
# ('fatma.txt', 'john.txt', 0.240610689472622)
# ('juma.txt', 'requirements.txt', 0.0)
# ('john.txt', 'juma.txt', 1.0)
# ('john.txt', 'requirements.txt', 0.0)
# ('fatma.txt', 'juma.txt', 0.240610689472622)
# ('fatma.txt', 'requirements.txt', 0.0)
